# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhangkhare/Learnings/blob/main/Python%20Library%20Dependencies%20Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # List of required libraries

# %%
libraries = ['transformers', 'spacy', 'accelerate', 'langdetect', 'nltk']

# %%
# !pip install transformers.configuration_utils
# Out:
# ERROR: Could not find a version that satisfies the requirement transformers.configuration_utils (from versions: none)
# ERROR: No matching distribution found for transformers.configuration_utils

# %%
import spacy, langdetect, nltk

# %% [markdown]
# # Import Required Libraries

# %%
import subprocess


for library in libraries:
    try:
        __import__(library)
        print(f"{library} is already installed.")
    except ImportError:
        print(f"{library} not found. Installing...")
        subprocess.run(["pip", "install", library])
        print(f"{library} installed successfully.")

# Now try importing again
for library in libraries:
    try:
        __import__(library)
        print(f"{library} imported successfully.")
    except ImportError:
        print(f"Failed to import {library}. Please check installation.")
# Out:
# transformers is already installed.
# spacy is already installed.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# /usr/lib/python3.10/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'transformers.configuration_utils'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-86-fb7eac17116b> in <cell line: 4>()
#       4 for library in libraries:
#       5     try:
# ----> 6         __import__(library)
#       7         print(f"{library} is already installed.")
#       8     except ImportError:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/__init__.py in <module>
#       1 __version__ = "0.25.0"
#       2
# ----> 3 from .accelerator import Accelerator
#       4 from .big_modeling import (
#       5     cpu_offload,
#
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py in <module>
#      33 import torch.utils.hooks as hooks
#      34
# ---> 35 from .checkpointing import load_accelerator_state, load_custom_state, save_accelerator_state, save_custom_state
#      36 from .data_loader import DataLoaderDispatcher, prepare_data_loader, skip_first_batches
#      37 from .hooks import AlignDevicesHook
#
# /usr/local/lib/python3.10/dist-packages/accelerate/checkpointing.py in <module>
#      22 from torch.cuda.amp import GradScaler
#      23
# ---> 24 from .utils import (
#      25     MODEL_NAME,
#      26     OPTIMIZER_NAME,
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/__init__.py in <module>
#     147
#     148 from .bnb import has_4bit_bnb_layers, load_and_quantize_model
# --> 149 from .fsdp_utils import load_fsdp_model, load_fsdp_optimizer, save_fsdp_model, save_fsdp_optimizer
#     150 from .launch import (
#     151     PrepareForLaunch,
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/fsdp_utils.py in <module>
#      23
#      24 if is_torch_version(">=", FSDP_PYTORCH_VERSION) and is_torch_distributed_available():
# ---> 25     import torch.distributed.checkpoint as dist_cp
#      26     from torch.distributed.checkpoint.default_planner import DefaultLoadPlanner, DefaultSavePlanner
#      27     from torch.distributed.checkpoint.optimizer import load_sharded_optimizer_state_dict
#
# /usr/local/lib/python3.10/dist-packages/torch/distributed/checkpoint/__init__.py in <module>
#       5     Metadata,
#       6 )
# ----> 7 from .state_dict_loader import load_state_dict
#       8 from .state_dict_saver import save_state_dict
#       9 from .storage import StorageReader, StorageWriter
#
# /usr/local/lib/python3.10/dist-packages/torch/distributed/checkpoint/state_dict_loader.py in <module>
#       8 )
#       9 from .planner import LoadPlanner
# ---> 10 from .default_planner import DefaultLoadPlanner
#      11
#      12 from .utils import _DistWrapper
#
# /usr/local/lib/python3.10/dist-packages/torch/distributed/checkpoint/default_planner.py in <module>
#      12
#      13 from torch.distributed._shard._utils import narrow_tensor_by_index
# ---> 14 from torch.distributed._tensor import DTensor
#      15
#      16
#
# /usr/local/lib/python3.10/dist-packages/torch/distributed/_tensor/__init__.py in <module>
#     317
#     318 if not torch._running_with_deploy():
# --> 319     import torch.distributed._tensor._dynamo_utils
#
# /usr/local/lib/python3.10/dist-packages/torch/distributed/_tensor/_dynamo_utils.py in <module>
# ----> 1 from torch._dynamo import allow_in_graph
#       2 from torch.distributed._tensor.api import DTensor
#       3
#       4 # dynamo/torch.compile utils for
#       5 allow_in_graph(DTensor)
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/__init__.py in <module>
#       1 import torch
# ----> 2 from . import allowed_functions, convert_frame, eval_frame, resume_execution
#       3 from .backends.registry import list_backends, register_backend
#       4 from .convert_frame import replay
#       5 from .decorators import (
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py in <module>
#      44 from .guards import CheckFunctionManager, GuardedCode
#      45 from .hooks import Hooks
# ---> 46 from .output_graph import OutputGraph
#      47 from .replay_record import ExecutionRecord
#      48 from .symbolic_convert import InstructionTranslator
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/output_graph.py in <module>
#      33 from torch.utils.weak import WeakIdKeyDictionary, WeakTensorKeyDictionary
#      34
# ---> 35 from . import config, logging as torchdynamo_logging, variables
#      36 from .backends.registry import CompiledFn, CompilerFn
#      37 from .bytecode_transformation import (
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/__init__.py in <module>
#      51     UnspecializedPythonVariable,
#      52 )
# ---> 53 from .torch import TorchVariable
#      54 from .user_defined import UserDefinedClassVariable, UserDefinedObjectVariable
#      55
#
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/variables/torch.py in <module>
#     129         return self.__dict__ == other.__dict__
#     130
# --> 131     transformers.configuration_utils.PretrainedConfig.__eq__ = (
#     132         _dynamo_overriden_transformers_eq
#     133     )
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# RuntimeError: Failed to import transformers.configuration_utils because of the following error (look up to see its traceback):
# No module named 'transformers.configuration_utils'

# %%
import transformers

# %% [markdown]
# # Get Dependencies

# %%
import pkg_resources
import pandas as pd

def get_dependency_info(package_name, seen_dependencies=None):
    if seen_dependencies is None:
        seen_dependencies = set()

    dependency_info = []

    try:
        distribution = pkg_resources.get_distribution(package_name)

        if package_name not in seen_dependencies:
            seen_dependencies.add(package_name)

            for dep in distribution.requires():
                dep_name = dep.project_name
                dep_specifier = dep.specifier
                latest_version = get_latest_version(dep_name)
                dependency_info.append({
                    'Library Name': dep_name,
                    'Versions Allowed': str(dep_specifier),
                    'Latest Version': latest_version
                })

                # Recursively call the function for each dependency
                dependency_info += get_dependency_info(dep_name, seen_dependencies)

    except pkg_resources.DistributionNotFound:
        print(f"Package {package_name} not found.")

    return dependency_info

def get_latest_version(package_name):
    try:
        distribution = pkg_resources.get_distribution(package_name)
        return distribution.version
    except pkg_resources.DistributionNotFound:
        return "Not Found"

# %%
import pkg_resources
import pandas as pd

def get_dependency_info(package_name, seen_dependencies=None):
    if seen_dependencies is None:
        seen_dependencies = set()

    dependency_info = []

    try:
        distribution = pkg_resources.get_distribution(package_name)

        if package_name not in seen_dependencies:
            seen_dependencies.add(package_name)

            # Include the original library in the output
            dependency_info.append({
                'Library Name': package_name,
                'Versions Allowed': 'Original Library',
                'Latest Version': get_latest_version(package_name)
            })

            for dep in distribution.requires():
                dep_name = dep.project_name
                dep_specifier = dep.specifier
                latest_version = get_latest_version(dep_name)
                dependency_info.append({
                    'Library Name': dep_name,
                    'Versions Allowed': str(dep_specifier),
                    'Latest Version': latest_version
                })

                # Recursively call the function for each dependency
                dependency_info += get_dependency_info(dep_name, seen_dependencies)

    except pkg_resources.DistributionNotFound:
        print(f"Package {package_name} not found.")

    return dependency_info

def get_latest_version(package_name):
    try:
        distribution = pkg_resources.get_distribution(package_name)
        return distribution.version
    except pkg_resources.DistributionNotFound:
        return "Not Found"

# %%
package_name = libraries  # Replace with your desired library
df_list = []

for package in package_name:
    df_temp = pd.DataFrame(get_dependency_info(package))
    df_list.append(df_temp)

# Concat dataframe
df = pd.concat(df_list, axis = 0).reset_index(False)
# Drop index column
df.drop(['index'], axis = 1, inplace= True)
# Drop duplicates based on 'Library Name'
df.drop_duplicates(subset='Library Name', keep='first', inplace=True)


# Display the Pandas DataFrame without duplicates
print(df)
# Out:
#            Library Name              Versions Allowed Latest Version
# 0          transformers              Original Library         4.35.2
# 1              filelock                                       3.13.1
# 3       huggingface-hub                 <1.0,>=0.16.4         0.19.4
# 6                fsspec                    >=2023.5.0       2023.6.0
# 8              requests                                       2.31.0
# 10   charset-normalizer                        <4,>=2          3.3.2
# 12                 idna                      <4,>=2.5            3.6
# 14              urllib3                   <3,>=1.21.1          2.0.7
# 16              certifi                   >=2017.4.17     2023.11.17
# 18                 tqdm                      >=4.42.1         4.66.1
# 20               pyyaml                         >=5.1          6.0.1
# 22    typing-extensions                     >=3.7.4.3          4.5.0
# 24            packaging                        >=20.9           23.2
# 26                numpy                        >=1.17         1.23.5
# 30                regex                  !=2019.12.17       2023.6.3
# 33           tokenizers                  <0.19,>=0.14         0.15.0
# 36          safetensors                       >=0.3.1          0.4.1
# 39                spacy              Original Library          3.6.1
# 40         spacy-legacy               <3.1.0,>=3.0.11         3.0.12
# 42        spacy-loggers                <2.0.0,>=1.0.0          1.0.5
# 44           murmurhash               <1.1.0,>=0.28.0         1.0.10
# 46                cymem                <2.1.0,>=2.0.2          2.0.8
# 48              preshed                <3.1.0,>=3.0.2          3.0.9
# 52                thinc                <8.2.0,>=8.1.8         8.1.12
# 54                 blis                <0.8.0,>=0.7.8         0.7.11
# 61               wasabi                <1.2.0,>=0.8.1          1.1.2
# 63                srsly                <3.0.0,>=2.4.0          2.4.8
# 65            catalogue                <2.1.0,>=2.0.3         2.0.10
# 68           confection                <1.0.0,>=0.0.1          0.1.4
# 70             pydantic  !=1.8,!=1.8.1,<3.0.0,>=1.7.4        1.10.13
# 75           setuptools                                       67.7.2
# 84                typer               <0.10.0,>=0.3.0          0.9.0
# 86                click                <9.0.0,>=7.1.1          8.1.7
# 89                pathy                      >=0.10.0         0.10.3
# 91           smart-open                <7.0.0,>=5.2.1          6.4.0
# 109              jinja2                                        3.1.2
# 111          MarkupSafe                         >=2.0          2.1.3
# 115           langcodes                <4.0.0,>=3.2.0          3.3.0
# 117          accelerate              Original Library         0.25.0
# 122              psutil                                        5.9.5
# 126               torch                      >=1.10.0    2.1.0+cu121
# 132               sympy                                         1.12
# 134              mpmath                        >=0.19          1.3.0
# 136            networkx                                        3.2.1
# 144              triton                       ==2.1.0          2.1.0
# 168          langdetect              Original Library          1.0.9
# 169                 six                                       1.16.0
# 171                nltk              Original Library          3.8.1
# 174              joblib                                        1.3.2

# %%
df.to_excel('Libraries.xlsx')

# %%
df.sample(10)
# Out:
#     Library Name              Versions Allowed Latest Version
# 14       urllib3                   <3,>=1.21.1          2.0.7
# 86         click                <9.0.0,>=7.1.1          8.1.7
# 111   MarkupSafe                         >=2.0          2.1.3
# 126        torch                      >=1.10.0    2.1.0+cu121
# 46         cymem                <2.1.0,>=2.0.2          2.0.8
# 52         thinc                <8.2.0,>=8.1.8         8.1.12
# 68    confection                <1.0.0,>=0.0.1          0.1.4
# 16       certifi                   >=2017.4.17     2023.11.17
# 115    langcodes                <4.0.0,>=3.2.0          3.3.0
# 70      pydantic  !=1.8,!=1.8.1,<3.0.0,>=1.7.4        1.10.13
